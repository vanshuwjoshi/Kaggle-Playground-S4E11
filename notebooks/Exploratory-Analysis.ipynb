# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("../data/train.csv")
data.head()
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0       Varanasi            Working Professional
# 2   2    Yuvraj    Male  33.0  Visakhapatnam                         Student
# 3   3    Yuvraj    Male  22.0         Mumbai            Working Professional
# 4   4      Rhea  Female  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# ...

# %%
data.shape
# Out:
# (140700, 20)

# %%
data.dtypes
# Out:
# id                                         int64
# Name                                      object
# Gender                                    object
# Age                                      float64
# City                                      object
# Working Professional or Student           object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# ...

# %% [markdown]
# Remove id, Name from train and test data

# %%
data = data.drop(["id", "Name"], axis=1)
data.head()
# Out:
#    Gender   Age           City Working Professional or Student  \
# 0  Female  49.0       Ludhiana            Working Professional
# 1    Male  26.0       Varanasi            Working Professional
# 2    Male  33.0  Visakhapatnam                         Student
# 3    Male  22.0         Mumbai            Working Professional
# 4  Female  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# 0                 NaN               2.0  More than 8 hours        Healthy
# ...

# %%
data.dtypes
# Out:
# Gender                                    object
# Age                                      float64
# City                                      object
# Working Professional or Student           object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
data.isna().sum()
# Out:
# Gender                                        0
# Age                                           0
# City                                          0
# Working Professional or Student               0
# Profession                                36630
# Academic Pressure                        112803
# Work Pressure                             27918
# CGPA                                     112802
# Study Satisfaction                       112803
# Job Satisfaction                          27910
# Sleep Duration                                0
# Dietary Habits                                4
# Degree                                        2
# Have you ever had suicidal thoughts ?         0
# Work/Study Hours                              0
# Financial Stress                              4
# Family History of Mental Illness              0
# Depression                                    0
# dtype: int64

# %% [markdown]
# ### Gender

# %%
plt.figure(figsize=(5, 3))
sns.countplot(data, x="Gender")
plt.title("Distribution of Gender")
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.countplot(data, x="Gender", hue="Depression")
plt.title("Distribution of Gender with Depression")
plt.legend(["No", "Yes"], loc="right")
plt.show()

# %%
plt.figure(figsize=(10, 3))
sns.histplot(data, x="Age", bins=40)
plt.title("Distribution of Age")
plt.show()

# %%
plt.figure(figsize=(10, 3))
sns.histplot(data, x="Age", hue="Depression", multiple="stack", bins=40)
plt.title("Distribution of Age with depression")
plt.legend(["No", "Yes"])
plt.show()

# %% [markdown]
# ### City

# %%
city_counts = data["City"].value_counts()

# %%
city_counts
# Out:
# City
# Kalyan         6591
# Patna          5924
# Vasai-Virar    5765
# Kolkata        5689
# Ahmedabad      5613
#                ...
# Shrey             1
# Ivaan             1
# Vaanya            1
# Gaurav            1
# Unirar            1
# Name: count, Length: 98, dtype: int64

# %% [markdown]
# Last few cities looks wrong. We need to look into it.

# %%
city_counts[city_counts == 3].index
# Out:
# Index(['Mahi', 'Vidya', 'City', 'Pratyush', 'Harsha', 'Saanvi', 'Bhavna'], dtype='object', name='City')

# %%
city_counts[city_counts == 2].index
# Out:
# Index(['Molkata', 'MCA', 'M.Com', 'Atharv', 'Nalini', 'Keshav', 'Ayush'], dtype='object', name='City')

# %%
city_counts[city_counts == 1].index
# Out:
# Index(['M.Tech', 'Researcher', 'Vaishnavi', 'Chhavi', 'Parth', 'Vidhi',
#        'Tushar', 'MSc', 'No', 'Rashi', 'ME', 'Ishanabad', 'Armaan', 'Kagan',
#        'Kashish', 'Ithal', 'Nalyan', 'Dhruv', 'Galesabad', 'Itheg', 'Aaradhya',
#        'Pooja', 'Khushi', 'Khaziabad', 'Jhanvi', 'Kibara', 'Harsh', 'Reyansh',
#        'Morena', 'Less Delhi', 'Malyansh', 'Aditya', 'Plata', 'Aishwarya',
#        '3.0', 'Less than 5 Kalyan', 'Krishna', 'Mira', 'Moreadhyay',
#        'Ishkarsh', 'Raghavendra', 'Kashk', 'Gurgaon', 'Tolkata', 'Anvi',
#        'Krinda', 'Ayansh', 'Shrey', 'Ivaan', 'Vaanya', 'Gaurav', 'Unirar'],
#       dtype='object', name='City')

# %%
city_counts[city_counts > 3].index
# Out:
# Index(['Kalyan', 'Patna', 'Vasai-Virar', 'Kolkata', 'Ahmedabad', 'Meerut',
#        'Ludhiana', 'Pune', 'Rajkot', 'Visakhapatnam', 'Srinagar', 'Mumbai',
#        'Indore', 'Agra', 'Surat', 'Varanasi', 'Vadodara', 'Hyderabad',
#        'Kanpur', 'Jaipur', 'Thane', 'Lucknow', 'Nagpur', 'Bangalore',
#        'Chennai', 'Ghaziabad', 'Delhi', 'Bhopal', 'Faridabad', 'Nashik',
#        'Mihir', 'Nandini'],
#       dtype='object', name='City')

# %% [markdown]
# - The cities that are present more than 3 times are fine.
# - "Molkata", "Tolkata" must be Kolkata
# - "Less Delhi" must be Delhi
# - The rest can be removed

# %%
data[data["City"] == "Molkata"]
# Out:
#         Gender   Age     City Working Professional or Student      Profession  \
# 100610  Female  48.0  Molkata            Working Professional            Chef
# 129223    Male  60.0  Molkata            Working Professional  Civil Engineer
#
#         Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 100610                NaN            3.0   NaN                 NaN
# 129223                NaN            1.0   NaN                 NaN
#
#         Job Satisfaction Sleep Duration Dietary Habits Degree  \
# 100610               5.0      7-8 hours        Healthy    BHM
# 129223               4.0      7-8 hours      Unhealthy    BSc
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 100610                                    No               5.0
# 129223                                   Yes               0.0
#
#         Financial Stress Family History of Mental Illness  Depression
# 100610               4.0                               No           0
# ...

# %%
#data.loc[data["City"] == "Molkata", "City"] = "Kolkata"

# %%
#data.loc[data["City"] == "Tolkata", "City"] = "Kolkata"

# %%
#data.loc[data["City"] == "Less Delhi", "City"] = "Delhi"

# %%
#city_counts = data["City"].value_counts()
#city_counts

# %%
#city_counts[city_counts <= 3].index

# %%
#cities_to_drop = city_counts[city_counts < 6].index
#cities_to_drop

# %%
#data = data[data["City"].isin(city_counts[city_counts > 6].index)]
#data["City"].value_counts()

# %%
plt.figure(figsize=(10, 10))
sns.histplot(data, y="City", hue="Depression", multiple="stack")
plt.title("Distribution of depression for each City")
plt.legend(["No", "Yes"])
plt.show()

# %% [markdown]
# - Lets look at the percentage of total population of each city that is depressed according to the survey.
# - Also we can look at the 4 metro cities of India - Delhi, Mumbai, Kolkata, and Chennai.

# %%
## Percentage of Depressed in each city
depression_percentage = data.groupby("City")["Depression"].mean() * 100
print(depression_percentage.sort_values(ascending=False))
# Out:
# City
# 3.0          100.0
# Mira         100.0
# Ishanabad    100.0
# Khaziabad    100.0
# Gaurav       100.0
#              ...
# Anvi           0.0
# Nalyan         0.0
# Nandini        0.0
# Kagan          0.0
# Galesabad      0.0
# Name: Depression, Length: 98, dtype: float64

# %%
depression_percentage_sorted = depression_percentage.sort_values(ascending=False)

# %%
plt.figure(figsize=(10, 8))
sns.barplot(
    y=depression_percentage_sorted.index,
    x=depression_percentage_sorted.values,
    palette="rocket",
)
plt.title("Percentage of depressed for each City")
plt.show()

# %%
metro_cities = ["Chennai", "Delhi", "Kolkata", "Mumbai"]
percentage_metro_cities = [
    depression_percentage["Chennai"],
    depression_percentage["Delhi"],
    depression_percentage["Kolkata"],
    depression_percentage["Mumbai"],
]

# %%
plt.figure(figsize=(10, 3))
sns.barplot(
    x=metro_cities,
    y=percentage_metro_cities,
    palette="rocket",
)
plt.title("Percentage of depressed for Metro Cities")
plt.show()

# %% [markdown]
# ### Working Professional or Student

# %%
print(
    "Number of null values in the Working Professional or Student column =",
    data["Working Professional or Student"].isna().sum(),
)
# Out:
# Number of null values in the Working Professional or Student column = 0

# %%
data["Working Professional or Student"].value_counts()
# Out:
# Working Professional or Student
# Working Professional    112799
# Student                  27901
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5, 3))
sns.histplot(data, x="Working Professional or Student", hue="Depression", multiple="stack")
plt.title("Distribution of depression for Working Professional or Student")
plt.legend(["No", "Yes"])
plt.show()

# %%
## Percentage of Depressed for "Working Professional or Student"
depression_percentage = data.groupby("Working Professional or Student")["Depression"].mean() * 100
depression_percentage_sorted = depression_percentage.sort_values(ascending=False)
print(depression_percentage_sorted)
# Out:
# Working Professional or Student
# Student                 58.549873
# Working Professional     8.183583
# Name: Depression, dtype: float64

# %%
plt.figure(figsize=(5, 3))
sns.barplot(
    x=depression_percentage_sorted.index,
    y=depression_percentage_sorted.values,
    palette="rocket",
)
plt.title("Percentage of depressed for Working Professional or Student")
plt.show()

# %% [markdown]
# ### Profession

# %%
print(
    "Number of null values in the Profession column =",
    data["Profession"].isna().sum(),
)
# Out:
# Number of null values in the Profession column = 36630

# %%
data["Profession"].value_counts()
# Out:
# Profession
# Teacher           24906
# Content Writer     7814
# Architect          4370
# Consultant         4229
# HR Manager         4022
#                   ...
# BBA                   1
# City Manager          1
# FamilyVirar           1
# B.Com                 1
# Yuvraj                1
# Name: count, Length: 64, dtype: int64

# %% [markdown]
# - Replace "Finanancial Analyst" with "Financial Analyst"

# %%
data.loc[data["Profession"] == "Finanancial Analyst", "Profession"] = (
    "Financial Analyst"
)

# %%
data["Profession"].value_counts()
# Out:
# Profession
# Teacher           24906
# Content Writer     7814
# Architect          4370
# Consultant         4229
# HR Manager         4022
#                   ...
# City Manager          1
# FamilyVirar           1
# B.Com                 1
# BE                    1
# Yuvraj                1
# Name: count, Length: 63, dtype: int64

# %%
data[data["Profession"] == "Academic"]
# Out:
#         Gender   Age         City Working Professional or Student Profession  \
# 23789     Male  50.0       Kanpur            Working Professional   Academic
# 36398     Male  52.0  Vasai-Virar            Working Professional   Academic
# 84949   Female  39.0        Patna            Working Professional   Academic
# 92626     Male  52.0       Meerut            Working Professional   Academic
# 121476  Female  60.0        Thane            Working Professional   Academic
#
#         Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 23789                 NaN            4.0   NaN                 NaN
# 36398                 NaN            2.0   NaN                 NaN
# 84949                 NaN            4.0   NaN                 NaN
# 92626                 NaN            2.0   NaN                 NaN
# 121476                NaN            1.0   NaN                 NaN
#
#         Job Satisfaction     Sleep Duration Dietary Habits  Degree  \
# ...

# %%
#data.loc[data["Profession"] == "Academic", "Profession"] = (
#   "Teacher"
#)

# %%
#data[data["Profession"] == "Student"]

# %%
#data.drop(index=11509, inplace=True)

# %%
#data.drop(index=88617, inplace=True)

# %%
#data[data["Profession"] == "Student"]

# %%
#data[data["Profession"] == "Yogesh"]

# %% [markdown]
# Since 2 out 3 of these have depression, we should keep them and rename the "Yogesh" to "Others".

# %%
#data.loc[data["Profession"] == "Yogesh", "Profession"] = (
#    "Other"
#)

# %%
#data[data["Profession"] == "PhD"]

# %%
#profession_counts = data["Profession"].value_counts()
#profession_counts[profession_counts <= 4]

# %%
#data = data[
#    data["Profession"].isin(profession_counts[profession_counts > 3].index)
#]

# %%
plt.figure(figsize=(10, 15))
sns.countplot(data, y="Profession", hue="Depression")
plt.title("Distribution of depression for each Profession")
plt.legend(["No", "Yes"])
plt.show()

# %%
depression_percentage = data.groupby("Profession")["Depression"].mean() * 100
depression_percentage_sorted = depression_percentage.sort_values(ascending=False)
plt.figure(figsize=(10, 12))
sns.barplot(
    y=depression_percentage_sorted.index,
    x=depression_percentage_sorted.values,
    palette="rocket",
)
plt.title("Percentage of depressed for each Profession")
plt.show()

# %% [markdown]
# ### Academic Pressure

# %%
data.shape
# Out:
# (140700, 18)

# %%
data["Academic Pressure"].value_counts()
# Out:
# Academic Pressure
# 3.0    7463
# 5.0    6296
# 4.0    5158
# 1.0    4801
# 2.0    4179
# Name: count, dtype: int64

# %%
data["Academic Pressure"].isnull().sum()
# Out:
# 112803

# %%
plt.figure(figsize=(5, 5))
sns.countplot(data, x="Academic Pressure", hue="Depression")
plt.title("Distribution of depression for Academic Pressure")
plt.legend(["No", "Yes"])
plt.show()

# %% [markdown]
# ### Work Pressure

# %%
data["Work Pressure"].value_counts()
# Out:
# Work Pressure
# 2.0    24373
# 4.0    22512
# 5.0    22436
# 3.0    21899
# 1.0    21562
# Name: count, dtype: int64

# %%
data["Work Pressure"].isnull().sum()
# Out:
# 27918

# %%
plt.figure(figsize=(5, 5))
sns.countplot(data, x="Work Pressure", hue="Depression")
plt.title("Distribution of depression for Work Pressure")
plt.legend(["No", "Yes"])
plt.show()

# %% [markdown]
# ### CGPA

# %%
data["CGPA"].value_counts()
# Out:
# CGPA
# 8.0400    822
# 9.9600    425
# 5.7400    410
# 8.9500    371
# 9.2100    343
#          ...
# 6.6400      1
# 7.0625      1
# 6.9800      1
# 6.4400      1
# 6.0900      1
# Name: count, Length: 331, dtype: int64

# %%
data["CGPA"].isnull().sum()
# Out:
# 112802

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data, x="CGPA", hue="Depression", multiple="stack", bins=40)
plt.title("Distribution of depression for CGPA")
plt.legend(["No", "Yes"])
plt.show()

# %%
def return_value_counts(col):
    return data[col].value_counts()


def return_null_values(col):
    return data[col].isnull().sum()


def display_count_plot(col):
    plt.figure(figsize=(5, 5))
    sns.countplot(data, x=col, hue="Depression")
    plt.title(str("Distribution of depression for " + col))
    plt.legend(["No", "Yes"])
    plt.show()

def display_count_plot_y(col):
    plt.figure(figsize=(10, 12))
    sns.countplot(data, y=col, hue="Depression")
    plt.title(str("Distribution of depression for " + col))
    plt.legend(["No", "Yes"])
    plt.show()

# %%
return_value_counts("Study Satisfaction")
# Out:
# Study Satisfaction
# 4.0    6360
# 2.0    5840
# 3.0    5823
# 1.0    5451
# 5.0    4423
# Name: count, dtype: int64

# %%
return_null_values("Study Satisfaction")
# Out:
# 112803

# %%
display_count_plot("Study Satisfaction")

# %% [markdown]
# ### Job Satisfaction

# %%
return_value_counts("Job Satisfaction")
# Out:
# Job Satisfaction
# 2.0    24783
# 5.0    22812
# 1.0    22324
# 3.0    21951
# 4.0    20920
# Name: count, dtype: int64

# %%
return_null_values("Job Satisfaction")
# Out:
# 27910

# %%
display_count_plot("Job Satisfaction")

# %% [markdown]
# ### Sleep Duration

# %%
return_value_counts("Sleep Duration")
# Out:
# Sleep Duration
# Less than 5 hours    38784
# 7-8 hours            36969
# More than 8 hours    32726
# 5-6 hours            32142
# 3-4 hours               12
# 6-7 hours                8
# 4-5 hours                7
# 2-3 hours                5
# 4-6 hours                5
# 6-8 hours                4
# 1-6 hours                4
# No                       4
# 9-11 hours               2
# 10-11 hours              2
# Sleep_Duration           2
# Unhealthy                2
# 45                       2
# 8-9 hours                2
# 10-6 hours               1
# 9-5                      1
# 45-48 hours              1
# 3-6 hours                1
# Work_Study_Hours         1
# 49 hours                 1
# than 5 hours             1
# Pune                     1
# 9-6 hours                1
# 8 hours                  1
# 35-36 hours              1
# Indore                   1
# 1-3 hours                1
# 55-66 hours              1
# Moderate                 1
# ...

# %%
return_null_values("Sleep Duration")
# Out:
# 0

# %%
display_count_plot_y("Sleep Duration")

# %% [markdown]
# ### Dietary Habits

# %%
return_null_values("Dietary Habits")
# Out:
# 4

# %%
return_value_counts("Dietary Habits")
# Out:
# Dietary Habits
# Moderate             49705
# Unhealthy            46227
# Healthy              44741
# Yes                      2
# No                       2
# More Healthy             2
# No Healthy               1
# Class 12                 1
# Indoor                   1
# Male                     1
# Vegas                    1
# M.Tech                   1
# Less Healthy             1
# 1.0                      1
# Electrician              1
# Hormonal                 1
# Mihir                    1
# Less than Healthy        1
# 3                        1
# Gender                   1
# BSc                      1
# Pratham                  1
# 2                        1
# Name: count, dtype: int64

# %%
display_count_plot_y("Dietary Habits")
